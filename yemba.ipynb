# %%
# !wget https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/74p9d5frg3-1.zip
# Out:
# --2024-12-24 03:50:35--  https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/74p9d5frg3-1.zip
# Resolving prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)... 52.92.16.50, 52.218.45.34, 3.5.64.6, ...
# Connecting to prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com)|52.92.16.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1107965721 (1.0G) [application/zip]
# Saving to: ‘74p9d5frg3-1.zip’
#
# 74p9d5frg3-1.zip    100%[===================>]   1.03G  97.1MB/s    in 15s
#
# 2024-12-24 03:50:50 (71.0 MB/s) - ‘74p9d5frg3-1.zip’ saved [1107965721/1107965721]

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
import zipfile
import os
os.makedirs('/content/drive/MyDrive/hackLang/', exist_ok=True)
with zipfile.ZipFile('/content/drive/MyDrive/hackLang/74p9d5frg3-1.zip', 'r') as zip_ref:
        # Extraire tous les fichiers dans le dossier spécifié
        zip_ref.extractall('/content/drive/MyDrive/hackLang/')
        print(f"Fichiers extraits dans {'YembaEGRA'}")
# Out:
# Fichiers extraits dans YembaEGRA

# %%
# import os
# import librosa
# import pandas as pd
# from datasets import Dataset

# # Chemin de votre dossier principal
# main_directory = '/content/YembaEGRA/YembaEGRA/audio/'
# word={
#     "W1":'Mbeŋ',
#     "W2":'Mbīŋ',
#     "W3":'Míá ntshi',
#     "W4":'Lekwɛ̄t',
#     "W5":'Meŋwɛ́’tsāŋ',
#     "W6":'Nzenzhɛ',
#     "W7":'Nu',
#     "W8":'Ŋgāp',
#     "W9":"Ŋkā’",
#     "W10":"Aphíɛ ntsō",
#     "W11":"Mɔ nzhɛ",
#     "W12":"Lefa’-Ntsō",
#     "W13":"Nzhɛ nchʉ-Nchʉ",
#     "W14":"Ŋgya meŋwa’ne",
#     "W15":"Mba ŋgɔpna apaka alā’",
#     "W16":"Ŋgya ntshi lepā",
#     "W17":"Menu ŋgɔpna",
#     "W18":"Ŋgya asikúu ",
#     "W19":"Akɛtte atii",
#     "W20":"Nzi’nɛ",
#     "W21":"Sɛ́h alaŋa",
#     "W22":"Mbuɔ́",
#     "W23":"Akia",
#     "W24":"Aŋwa’ne",
#     "W25":"Atetá azwiite",
#     "W26":"Aŋŋɛtte hániaŋ",
#     "W27":"Ŋkɔ’ɔ́ lɔ́kta",
#     "W28":"Ajʉ’ɛ́ ŋgɔ̄ŋ",
#     "W29":"Ashuŋɔ",
#     "W30":"Afa’a Téla",
#     "W31":"Lekɔ metsō",
#     "W32":"Ŋkɔɔ́ athū",
#     "W33":"Aneŋɛ mena",
#     "W34":"Mba Letshíɛ́ metúa",
#     "W35":"Ŋgya leziŋ",
#     "W36":"Mba letshiɛ́ metúa lephū",
#     "W37":"Metúa Ntshi",
#     "W38":"Mba letshiɛ́ metúa ntshi",
#     "W39":"Kwáŋ mé ntǝ̄",
#     "W40":"Metúa",
#     "W41":"Metúa lephū",
#     "W42":"Mbaŋa afho",
#     "W43":"Leswiá’ Lɔ́kta",
#     "W44":"Ayɛt-eféŋ",
#     "W45":"Mɔ lɔ́kta",
#     "W46":"Míá Lɔ́kta",
#     "W47":"Akɛttɛ afho",
#     "W48":"Kamɛlɛ",
#     "W49":"Mbalɔŋ",
#     "W50":"Leká",
#     "W51":"Ntǝm mbalɔŋ",
#     "W52":"Ntɔŋ lǝká",
#     "W53":"Mbalɔŋ mbū",
#     "W54":"Elaŋ mbalɔŋ",
#     "W55":"Atetá aka’te mbalɔŋ",
#     "W56":"Nzhɛ lekʉʉ",
#     "W57":"Atsá’",
#     "W58":"Menēk saŋ",
#     "W59":"Saŋ",
#     "W60":"Ŋgɔŋ atsetsá’",


# }
# # Liste pour stocker les données
# data = []  # Utiliser une liste pour stocker les dictionnaires

# # Parcourir tous les sous-dossiers dans le dossier principal
# for i in ['CI1','CI2','CI3','CI4','CI5','CI6','CI7','CI8']:
#   for root, dirs, files in os.walk(main_directory+i):
#       for file_name in files:
#           file_path = os.path.join(root, file_name)
#           dir_name = os.path.basename(root)  # Extraire le nom du dossier courant

#           # Charger l'audio
#           audio_array, sampling_rate = librosa.load(file_path, sr=None)

#           # Créer une entrée pour chaque fichier
#           entry = {
#               "text": word[dir_name],  # Nom du dossier
#               "audio": {
#                   "path": file_path,
#                   "array": audio_array,
#                   "sampling_rate": sampling_rate
#               },
#               "file": file_path,  # Chemin du fichier
#               "id": len(data) + 1  # Identifiant unique
#           }
#           data.append(entry)  # Ajouter l'entrée à la liste

# # Créer un DataFrame à partir de la liste de dictionnaires

# df = pd.DataFrame(data)
# # # df['text'] = df['text'].replace(word)
# # # Convertir le DataFrame en un Dataset Hugging Face
# # dataset2 = Dataset.from_pandas(df)

# # # Afficher le Dataset
# # print(dataset2)

# %%
import os
import librosa
import pandas as pd
from datasets import Dataset

# Chemin de votre dossier principal
main_directory = '/content/drive/MyDrive/hackLang/YembaEGRA/YembaEGRA/audio/'
word={
    "W1":'Mbeŋ',
    "W2":'Mbīŋ',
    "W3":'Míá ntshi',
    "W4":'Lekwɛ̄t',
    "W5":'Meŋwɛ́’tsāŋ',
    "W6":'Nzenzhɛ',
    "W7":'Nu',
    "W8":'Ŋgāp',
    "W9":"Ŋkā’",
    "W10":"Aphíɛ ntsō",
    "W11":"Mɔ nzhɛ",
    "W12":"Lefa’-Ntsō",
    "W13":"Nzhɛ nchʉ-Nchʉ",
    "W14":"Ŋgya meŋwa’ne",
    "W15":"Mba ŋgɔpna apaka alā’",
    "W16":"Ŋgya ntshi lepā",
    "W17":"Menu ŋgɔpna",
    "W18":"Ŋgya asikúu ",
    "W19":"Akɛtte atii",
    "W20":"Nzi’nɛ",
    "W21":"Sɛ́h alaŋa",
    "W22":"Mbuɔ́",
    "W23":"Akia",
    "W24":"Aŋwa’ne",
    "W25":"Atetá azwiite",
    "W26":"Aŋŋɛtte hániaŋ",
    "W27":"Ŋkɔ’ɔ́ lɔ́kta",
    "W28":"Ajʉ’ɛ́ ŋgɔ̄ŋ",
    "W29":"Ashuŋɔ",
    "W30":"Afa’a Téla",
    "W31":"Lekɔ metsō",
    "W32":"Ŋkɔɔ́ athū",
    "W33":"Aneŋɛ mena",
    "W34":"Mba Letshíɛ́ metúa",
    "W35":"Ŋgya leziŋ",
    "W36":"Mba letshiɛ́ metúa lephū",
    "W37":"Metúa Ntshi",
    "W38":"Mba letshiɛ́ metúa ntshi",
    "W39":"Kwáŋ mé ntǝ̄",
    "W40":"Metúa",
    "W41":"Metúa lephū",
    "W42":"Mbaŋa afho",
    "W43":"Leswiá’ Lɔ́kta",
    "W44":"Ayɛt-eféŋ",
    "W45":"Mɔ lɔ́kta",
    "W46":"Míá Lɔ́kta",
    "W47":"Akɛttɛ afho",
    "W48":"Kamɛlɛ",
    "W49":"Mbalɔŋ",
    "W50":"Leká",
    "W51":"Ntǝm mbalɔŋ",
    "W52":"Ntɔŋ lǝká",
    "W53":"Mbalɔŋ mbū",
    "W54":"Elaŋ mbalɔŋ",
    "W55":"Atetá aka’te mbalɔŋ",
    "W56":"Nzhɛ lekʉʉ",
    "W57":"Atsá’",
    "W58":"Menēk saŋ",
    "W59":"Saŋ",
    "W60":"Ŋgɔŋ atsetsá’",


}
# Liste pour stocker les données
data = []  # Utiliser une liste pour stocker les dictionnaires

# Parcourir tous les sous-dossiers dans le dossier principal
for i in ['CI2']:
  for root, dirs, files in os.walk(main_directory+i):
      for file_name in files:
          file_path = os.path.join(root, file_name)
          dir_name = os.path.basename(root)  # Extraire le nom du dossier courant

          # Charger l'audio
          audio_array, sampling_rate = librosa.load(file_path, sr=None)

          # Créer une entrée pour chaque fichier
          entry = {
              "text": word[dir_name],  # Nom du dossier
              "audio": {
                  "path": file_path,
                  "array": audio_array,
                  "sampling_rate": sampling_rate
              },
              "file": file_path,  # Chemin du fichier
              "id": len(data) + 1  # Identifiant unique
          }
          data.append(entry)  # Ajouter l'entrée à la liste

# Créer un DataFrame à partir de la liste de dictionnaires

df = pd.DataFrame(data)
# # df['text'] = df['text'].replace(word)
# # Convertir le DataFrame en un Dataset Hugging Face
# dataset2 = Dataset.from_pandas(df)

# # Afficher le Dataset
# print(dataset2)

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# import pandas as pd
# df=pd.read_csv('/yemba.csv')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset

# Charger votre DataFrame
dataset = df  # Remplacez par le chemin de votre fichier

# Diviser le DataFrame en données d'entraînement et de test
train_data, test_data = train_test_split(dataset, test_size=0.2, random_state=42)
datasetTrain = Dataset.from_pandas(train_data)
datasetTest = Dataset.from_pandas(test_data)
from datasets import load_dataset, DatasetDict

common_voice = DatasetDict()

common_voice["train"] = datasetTrain
common_voice["test"] = datasetTest
print(common_voice)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'audio', 'file', 'id', '__index_level_0__'],
#         num_rows: 956
#     })
#     test: Dataset({
#         features: ['text', 'audio', 'file', 'id', '__index_level_0__'],
#         num_rows: 239
#     })
# })

# %%
common_voice = common_voice.select_columns(["audio", "text"])

# %%
from transformers import WhisperProcessor

processor = WhisperProcessor.from_pretrained(
    "/content/drive/MyDrive/hackLang/whisper_outputs/whisper-small-yemba", language="swahili", task="transcribe"
)

# %%
from datasets import Audio

sampling_rate = processor.feature_extractor.sampling_rate
common_voice = common_voice.cast_column("audio", Audio(sampling_rate=sampling_rate))

# %%
def prepare_dataset(example):
    audio = example["audio"]

    example = processor(
        audio=audio["array"],
        sampling_rate=audio["sampling_rate"],
        text=example["text"],
    )
    # compute input length of audio sample in seconds
    example["input_length"] = len(audio["array"]) / audio["sampling_rate"]

    return example

# %%
common_voice["train"][100]
# Out:
# {'audio': {'path': None,
#   'array': array([-0.00255447, -0.00445851, -0.00400643, ..., -0.0122635 ,
#          -0.01545234, -0.01197242]),
#   'sampling_rate': 16000},
#  'text': 'Lefa’-Ntsō'}

# %%
common_voice = common_voice.map(
    prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=1
)
# Out:
# ...
# Map:   0%|          | 0/239 [00:00<?, ? examples/s]

# %%
max_input_length = 30.0

def is_audio_in_length_range(length):
    return length < max_input_length

# %%
common_voice["train"] = common_voice["train"].filter(
    is_audio_in_length_range,
    input_columns=["input_length"],
)
# Out:
# Filter:   0%|          | 0/956 [00:00<?, ? examples/s]

# %%
common_voice["train"]
# Out:
# Dataset({
#     features: ['input_features', 'labels', 'input_length'],
#     num_rows: 956
# })

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union


@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:
        # diviser les entrées et les étiquettes car elles doivent être de longueurs différentes et nécessitent des méthodes de remplissage différentes
        # traiter d'abord les entrées audio en renvoyant simplement des tenseurs Torch
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # obtenir les séquences d'étiquettes tokenisées
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # rembourrer les étiquettes à la longueur maximale
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # remplacer le remplissage par -100 pour ignorer correctement les pertes
        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )

        # si le token bos est ajouté lors de l'étape de tokenisation précédente, couper le token bos ici puisqu'il sera de toute façon ajouté plus tard
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.7 MB/s eta 0:00:00
# ...

# %%
pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.8 MB/s eta 0:00:00
# ...

# %%
import evaluate

metric = evaluate.load("wer")

# %%
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

normalizer = BasicTextNormalizer()
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # remplacer -100 par pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # nous ne voulons pas grouper les *tokens* lors du calcul des métriques
    pred_str = processor.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = processor.batch_decode(label_ids, skip_special_tokens=True)

    # calculer le Wer orthographique
    wer_ortho = 100 * metric.compute(predictions=pred_str, references=label_str)

    # calculer le WER normalisé
    pred_str_norm = [normalizer(pred) for pred in pred_str]
    label_str_norm = [normalizer(label) for label in label_str]
    # afin de n'évaluer que les échantillons correspondant à des références non nulles
    pred_str_norm = [
        pred_str_norm[i] for i in range(len(pred_str_norm)) if len(label_str_norm[i]) > 0
    ]
    label_str_norm = [
        label_str_norm[i]
        for i in range(len(label_str_norm))
        if len(label_str_norm[i]) > 0
    ]

    wer = 100 * metric.compute(predictions=pred_str_norm, references=label_str_norm)

    return {"wer_ortho": wer_ortho, "wer": wer}

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("/content/drive/MyDrive/hackLang/whisper_outputs/whisper-small-yemba")
# model = model.to(device)

# %%
from functools import partial

# désactiver le cache pendant l'entraînement car il est incompatible avec le checkpointing du gradient
model.config.use_cache = False

# définir la langue et la tâche pour la génération et réactiver le cache
model.generate = partial(
    model.generate, language="swahili", task="transcribe", use_cache=True
)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from transformers import Seq2SeqTrainingArguments
training_args = Seq2SeqTrainingArguments(
    output_dir="/content/drive/MyDrive/whisper_outputs/whisper-small-yemba2",  # nom sur le Hub
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,  # à x2  pour chaque diminution de 2x de la taille du batch
    learning_rate=1e-5,
    lr_scheduler_type="constant_with_warmup",
    warmup_steps=50,
    max_steps=500,  # augmenter jusqu'à 4000 si vous disposez de votre propre GPU ou d'un plan Colab payant
    gradient_checkpointing=True,
    fp16=True,
    fp16_full_eval=True,
    eval_strategy="steps",
    per_device_eval_batch_size=16,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
)

# %%
pip install --upgrade transformers accelerate

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor,
)
# Out:
# <ipython-input-73-6add8000ae4f>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='364' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [364/500 25:17 < 09:30, 0.24 it/s, Epoch 6.05/9]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
from transformers import pipeline
pipe = pipeline("automatic-speech-recognition", model="/content/drive/MyDrive/hackLang/whisper_outputs/whisper-small-yemba")
# Out:
# Device set to use cuda:0

# %%
x=pipe('/content/drive/MyDrive/hackLang/YembaEGRA/YembaEGRA/audio/CI8/W57/spkr_10_word_57_occ_1_ci_8_l_3.wav)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:512: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
x
# Out:
# {'text': 'Apš́á’'}

# %%
kwargs = {
    "dataset_tags": "mozilla-foundation/common_voice_13_0",
    "dataset": "Common Voice 13",  # a 'pretty' name for the training dataset
    "language": "dv",
    "model_name": "Whisper Small Dv - Sanchit Gandhi",  # a 'pretty' name for your model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
}

# %%
# trainer.push_to_hub(**kwargs)

# %%
# from transformers import pipeline

# pipe = pipeline("automatic-speech-recognition", model="openai/whisper-small")
